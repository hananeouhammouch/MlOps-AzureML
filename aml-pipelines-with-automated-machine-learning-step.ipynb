# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.19.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-131418
# aml-quickstarts-131418
# southcentralus
# 9b72f9e6-56c5-4c16-991b-19c652994860

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'auto-ml-exp'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: auto-ml-exp,
# Workspace: quick-starts-ws-131418)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "cpu-cluster"


# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS3_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=5)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes =2)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "Bank-marketing"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 15,
    "max_concurrent_iterations":4,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [0ce3fde9][5bcfaea5-6f47-47cc-ac04-5213a17552a8], (This step will run and generate new outputs)
# Submitted PipelineRun fe54ada0-1665-4ad8-b19d-7b5e557fa07e
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/auto-ml-exp/runs/fe54ada0-1665-4ad8-b19d-7b5e557fa07e?wsid=/subscriptions/9b72f9e6-56c5-4c16-991b-19c652994860/resourcegroups/aml-quickstarts-131418/workspaces/quick-starts-ws-131418

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: fe54ada0-1665-4ad8-b19d-7b5e557fa07e
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/auto-ml-exp/runs/fe54ada0-1665-4ad8-b19d-7b5e557fa07e?wsid=/subscriptions/9b72f9e6-56c5-4c16-991b-19c652994860/resourcegroups/aml-quickstarts-131418/workspaces/quick-starts-ws-131418
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
# WARNING:azureml.pipeline.core.run:Expected a StepRun object but received <class 'azureml.core.run.Run'> instead.
# This usually indicates a package conflict with one of the dependencies of azureml-core or azureml-pipeline-core.
# Please check for package conflicts in your python environment
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'fe54ada0-1665-4ad8-b19d-7b5e557fa07e', 'status': 'Completed', 'startTimeUtc': '2020-12-22T22:12:23.895805Z', 'endTimeUtc': '2020-12-22T22:47:55.958027Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg131418.blob.core.windows.net/azureml/ExperimentRun/dcid.fe54ada0-1665-4ad8-b19d-7b5e557fa07e/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=uBKVB7rQQ%2B5hp%2FUAbe5iVy2b8xglEotsVzYNB698blA%3D&st=2020-12-22T22%3A02%3A45Z&se=2020-12-23T06%3A12%3A45Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg131418.blob.core.windows.net/azureml/ExperimentRun/dcid.fe54ada0-1665-4ad8-b19d-7b5e557fa07e/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=iO1E6GJ6YKZVQSJgrx8MehwJp6%2BUTTgfD8EjFY4eaDU%3D&st=2020-12-22T22%3A02%3A45Z&se=2020-12-23T06%3A12%3A45Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg131418.blob.core.windows.net/azureml/ExperimentRun/dcid.fe54ada0-1665-4ad8-b19d-7b5e557fa07e/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=wOYv1c7TSYjXRXeJVNyku2gNqkaicI7iwn0ZnV0hk9I%3D&st=2020-12-22T22%3A02%3A45Z&se=2020-12-23T06%3A12%3A45Z&sp=r'}}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/31a8f998-cd15-4050-9109-5ee3adf714c9/metrics_data
# Downloaded azureml/31a8f998-cd15-4050-9109-5ee3adf714c9/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  31a8f998-cd15-4050-9109-5ee3adf714c9_20  \
# precision_score_macro                               [0.7873023436711378]
# recall_score_micro                                  [0.9077389984825494]
# f1_score_weighted                                   [0.8971238918213456]
# weighted_accuracy                                   [0.9644656358962787]
# precision_score_micro                               [0.9077389984825494]
# AUC_macro                                           [0.9329981457709313]
# average_precision_score_micro                       [0.9775048906893984]
# f1_score_micro                                      [0.9077389984825494]
# matthews_correlation                                [0.4538726815046628]
# balanced_accuracy                                   [0.6792540293823991]
# recall_score_macro                                  [0.6792540293823991]
# AUC_weighted                                        [0.9329981457709314]
# precision_score_weighted                             [0.895092517403297]
# AUC_micro                                           [0.9763877305247063]
# log_loss                                           [0.19994256312838007]
# average_precision_score_weighted                    [0.9474347924918001]
# norm_macro_recall                                   [0.3585080587647982]
# average_precision_score_macro                       [0.7953500733144905]
# recall_score_weighted                               [0.9077389984825494]
# accuracy                                            [0.9077389984825494]
# f1_score_macro                                        [0.71617170693669]
#
#                                  31a8f998-cd15-4050-9109-5ee3adf714c9_29  \
# precision_score_macro                               [0.7775270128436137]
# recall_score_micro                                  [0.9104704097116844]
# f1_score_weighted                                    [0.908507861755775]
# weighted_accuracy                                   [0.9492661052651428]
# precision_score_micro                               [0.9104704097116844]
# AUC_macro                                           [0.9398690740154156]
# average_precision_score_micro                       [0.9789562649261798]
# f1_score_micro                                      [0.9104704097116844]
# matthews_correlation                                [0.5312235869489556]
# balanced_accuracy                                    [0.754208136749857]
# recall_score_macro                                   [0.754208136749857]
# AUC_weighted                                        [0.9398690740154155]
# precision_score_weighted                            [0.9069279514776665]
# AUC_micro                                           [0.9778816941104953]
# log_loss                                            [0.1855736119800093]
# average_precision_score_weighted                    [0.9483146285848408]
# norm_macro_recall                                    [0.508416273499714]
# average_precision_score_macro                       [0.7957648112086436]
# recall_score_weighted                               [0.9104704097116844]
# accuracy                                            [0.9104704097116844]
# f1_score_macro                                      [0.7651297153769148]
#
#                                  31a8f998-cd15-4050-9109-5ee3adf714c9_26  \
# precision_score_macro                               [0.7764328692696766]
# recall_score_micro                                  [0.9101669195751139]
# f1_score_weighted                                   [0.9083753199793789]
# weighted_accuracy                                   [0.9486357041573478]
# precision_score_micro                               [0.9101669195751139]
# AUC_macro                                           [0.9386150149949892]
# average_precision_score_micro                       [0.9783025231706843]
# f1_score_micro                                      [0.9101669195751139]
# matthews_correlation                                [0.5312309488431649]
# balanced_accuracy                                   [0.7552213868003341]
# recall_score_macro                                  [0.7552213868003341]
# AUC_weighted                                        [0.9386150149949893]
# precision_score_weighted                            [0.9069013800026041]
# AUC_micro                                           [0.9773262012383687]
# log_loss                                            [0.2320866824219174]
# average_precision_score_weighted                    [0.9494719102600525]
# norm_macro_recall                                   [0.5104427736006683]
# average_precision_score_macro                       [0.8022470859728432]
# recall_score_weighted                               [0.9101669195751139]
# accuracy                                            [0.9101669195751139]
# f1_score_macro                                      [0.7652153147826823]
#
#                                  31a8f998-cd15-4050-9109-5ee3adf714c9_9  \
# precision_score_macro                              [0.5991816493999552]
# recall_score_micro                                 [0.7110773899848255]
# f1_score_weighted                                  [0.7628371092713555]
# weighted_accuracy                                  [0.7076634722741361]
# precision_score_micro                              [0.7110773899848255]
# AUC_macro                                           [0.819050119756153]
# average_precision_score_micro                      [0.7952949009231616]
# f1_score_micro                                     [0.7110773899848254]
# matthews_correlation                               [0.2986557693477127]
# balanced_accuracy                                  [0.7248280531335731]
# recall_score_macro                                 [0.7248280531335731]
# AUC_weighted                                        [0.819050119756153]
# precision_score_weighted                           [0.8761588117189419]
# AUC_micro                                          [0.8129228771233372]
# log_loss                                           [0.5656353039900436]
# average_precision_score_weighted                   [0.9120022322108672]
# norm_macro_recall                                 [0.44965610626714625]
# average_precision_score_macro                      [0.7115116070187726]
# recall_score_weighted                              [0.7110773899848255]
# accuracy                                           [0.7110773899848255]
# f1_score_macro                                     [0.5891499672560577]
#
#                                  31a8f998-cd15-4050-9109-5ee3adf714c9_25  \
# precision_score_macro                               [0.7841169254587081]
# recall_score_micro                                  [0.9116843702579667]
# f1_score_weighted                                   [0.9080332941250415]
# weighted_accuracy                                    [0.954139612862666]
# precision_score_micro                               [0.9116843702579667]
# AUC_macro                                             [0.94536414947198]
# average_precision_score_micro                       [0.9806660733379502]
# f1_score_micro                                      [0.9116843702579667]
# matthews_correlation                                 [0.522998482568272]
# balanced_accuracy                                   [0.7406820821454968]
# recall_score_macro                                  [0.7406820821454968]
# AUC_weighted                                          [0.94536414947198]
# precision_score_weighted                             [0.905693502555877]
# AUC_micro                                           [0.9797258457081935]
# log_loss                                            [0.1788837639886998]
# average_precision_score_weighted                     [0.953056260912226]
# norm_macro_recall                                   [0.4813641642909936]
# average_precision_score_macro                       [0.8145589827980431]
# recall_score_weighted                               [0.9116843702579667]
# accuracy                                            [0.9116843702579667]
# f1_score_macro                                      [0.7598459659998121]
#
#                                  31a8f998-cd15-4050-9109-5ee3adf714c9_45  \
# precision_score_macro                               [0.4440060698027314]
# recall_score_micro                                  [0.8880121396054628]
# f1_score_weighted                                   [0.8353395018439429]
# weighted_accuracy                                   [0.9843450583187134]
# precision_score_micro                               [0.8880121396054628]
# AUC_macro                                                          [0.5]
# average_precision_score_micro                       [0.8445594902839405]
# f1_score_micro                                      [0.8880121396054628]
# matthews_correlation                                               [0.0]
# balanced_accuracy                                                  [0.5]
# recall_score_macro                                                 [0.5]
# AUC_weighted                                                       [0.5]
# precision_score_weighted                             [0.788565560086672]
# AUC_micro                                           [0.8880121396054628]
# log_loss                                            [0.3544360825859125]
# average_precision_score_weighted                    [0.8011068409624182]
# norm_macro_recall                                                  [0.0]
# average_precision_score_macro                                      [0.5]
# recall_score_weighted                               [0.8880121396054628]
# accuracy                                            [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
#
#                                  31a8f998-cd15-4050-9109-5ee3adf714c9_47  \
# precision_score_macro                               [0.7956571127070715]
# recall_score_micro                                  [0.9156297420333839]
# f1_score_weighted                                   [0.9122029436860406]
# weighted_accuracy                                    [0.956455069348146]
# precision_score_micro                               [0.9156297420333839]
# AUC_macro                                           [0.9478546699342592]
# average_precision_score_micro                       [0.9815306242367388]
# f1_score_micro                                      [0.9156297420333839]
# matthews_correlation                                [0.5450388598016137]
# balanced_accuracy                                     [0.75119246749542]
# recall_score_macro                                    [0.75119246749542]
# AUC_weighted                                        [0.9478546699342592]
# precision_score_weighted                            [0.9100808401175083]
# AUC_micro                                           [0.9806376056055872]
# log_loss                                           [0.18773871423551533]
# average_precision_score_weighted                     [0.955547744290648]
# norm_macro_recall                                     [0.50238493499084]
# average_precision_score_macro                       [0.8245184422098437]
# recall_score_weighted                               [0.9156297420333839]
# accuracy                                            [0.9156297420333839]
# f1_score_macro                                      [0.7708751473286735]
#
#                                  31a8f998-cd15-4050-9109-5ee3adf714c9_7  \
# precision_score_macro                              [0.4440060698027314]
# recall_score_micro                                 [0.8880121396054628]
# f1_score_weighted                                  [0.8353395018439429]
# weighted_accuracy                                  [0.9843450583187134]
# precision_score_micro                              [0.8880121396054628]
# AUC_macro                                          [0.8151226180751214]
# average_precision_score_micro                      [0.9469217619974519]
# f1_score_micro                                     [0.8880121396054628]
# matthews_correlation                                              [0.0]
# balanced_accuracy                                                 [0.5]
# recall_score_macro                                                [0.5]
# AUC_weighted                                       [0.8151226180751214]
# precision_score_weighted                            [0.788565560086672]
# AUC_micro                                          [0.9506878725986171]
# log_loss                                          [0.28570524274382514]
# average_precision_score_weighted                   [0.9068509006845124]
# norm_macro_recall                                                 [0.0]
# average_precision_score_macro                       [0.700602835355278]
# recall_score_weighted                              [0.8880121396054628]
# accuracy                                           [0.8880121396054628]
# f1_score_macro                                     [0.4703423886834914]
#
#                                  31a8f998-cd15-4050-9109-5ee3adf714c9_13  \
# precision_score_macro                                [0.822098675416211]
# recall_score_micro                                  [0.9062215477996965]
# f1_score_weighted                                    [0.885603431576398]
# weighted_accuracy                                   [0.9766010009385309]
# precision_score_micro                               [0.9062215477996965]
# AUC_macro                                           [0.9308878256246677]
# average_precision_score_micro                       [0.9766643355999638]
# f1_score_micro                                      [0.9062215477996965]
# matthews_correlation                                [0.3976739324324451]
# balanced_accuracy                                   [0.6227454260188535]
# recall_score_macro                                  [0.6227454260188535]
# AUC_weighted                                        [0.9308878256246675]
# precision_score_weighted                            [0.8929725418691179]
# AUC_micro                                           [0.9758990146932517]
# log_loss                                           [0.33655623030329523]
# average_precision_score_weighted                     [0.947605275820125]
# norm_macro_recall                                  [0.24549085203770704]
# average_precision_score_macro                       [0.7985126174047921]
# recall_score_weighted                               [0.9062215477996965]
# accuracy                                            [0.9062215477996965]
# f1_score_macro                                      [0.6650154684677185]
#
#                                  31a8f998-cd15-4050-9109-5ee3adf714c9_14  ...  \
# precision_score_macro                               [0.8807135865146916]  ...
# recall_score_micro                                   [0.896206373292868]  ...
# f1_score_weighted                                   [0.8565547658278334]  ...
# weighted_accuracy                                   [0.9840206023774044]  ...
# precision_score_micro                                [0.896206373292868]  ...
# AUC_macro                                           [0.8906773585849325]  ...
# average_precision_score_micro                        [0.966764898883203]  ...
# f1_score_micro                                       [0.896206373292868]  ...
# matthews_correlation                               [0.25442186361319014]  ...
# balanced_accuracy                                   [0.5425060248551904]  ...
# recall_score_macro                                  [0.5425060248551904]  ...
# AUC_weighted                                        [0.8906773585849325]  ...
# precision_score_weighted                            [0.8930125793094128]  ...
# AUC_micro                                           [0.9658670768465577]  ...
# log_loss                                            [0.2630867348117303]  ...
# average_precision_score_weighted                    [0.9301897874299847]  ...
# norm_macro_recall                                  [0.08501204971038079]  ...
# average_precision_score_macro                       [0.7425242377347006]  ...
# recall_score_weighted                                [0.896206373292868]  ...
# accuracy                                             [0.896206373292868]  ...
# f1_score_macro                                      [0.5511657288155035]  ...
#
#                                  31a8f998-cd15-4050-9109-5ee3adf714c9_32  \
# precision_score_macro                               [0.7570766491542149]
# recall_score_micro                                  [0.9031866464339909]
# f1_score_weighted                                   [0.9019419647024357]
# weighted_accuracy                                   [0.9426621276560521]
# precision_score_micro                               [0.9031866464339909]
# AUC_macro                                            [0.928626999872186]
# average_precision_score_micro                       [0.9756920147875687]
# f1_score_micro                                      [0.9031866464339909]
# matthews_correlation                                [0.5010971954539231]
# balanced_accuracy                                   [0.7441863157524262]
# recall_score_macro                                  [0.7441863157524262]
# AUC_weighted                                         [0.928626999872186]
# precision_score_weighted                            [0.9008254998831058]
# AUC_micro                                           [0.9753401138893942]
# log_loss                                            [0.1968869738472605]
# average_precision_score_weighted                    [0.9448518410708548]
# norm_macro_recall                                  [0.48837263150485244]
# average_precision_score_macro                       [0.7879430412580624]
# recall_score_weighted                               [0.9031866464339909]
# accuracy                                            [0.9031866464339909]
# f1_score_macro                                      [0.7503871462459342]
#
#                                  31a8f998-cd15-4050-9109-5ee3adf714c9_37  \
# precision_score_macro                               [0.7783675282842227]
# recall_score_micro                                  [0.9092564491654022]
# f1_score_weighted                                   [0.9046980278562795]
# weighted_accuracy                                   [0.9543881861245762]
# precision_score_micro                               [0.9092564491654022]
# AUC_macro                                           [0.9376327922541016]
# average_precision_score_micro                       [0.9786568577363454]
# f1_score_micro                                       [0.909256449165402]
# matthews_correlation                                [0.5032744557092932]
# balanced_accuracy                                      [0.7274737101438]
# recall_score_macro                                     [0.7274737101438]
# AUC_weighted                                        [0.9376327922541016]
# precision_score_weighted                            [0.9020036460135082]
# AUC_micro                                           [0.9775822566494964]
# log_loss                                            [0.1884839505873889]
# average_precision_score_weighted                    [0.9496772796951003]
# norm_macro_recall                                  [0.45494742028760005]
# average_precision_score_macro                       [0.8030506731768436]
# recall_score_weighted                               [0.9092564491654022]
# accuracy                                            [0.9092564491654022]
# f1_score_macro                                      [0.7492862506905917]
#
#                                  31a8f998-cd15-4050-9109-5ee3adf714c9_34  \
# precision_score_macro                               [0.4440060698027314]
# recall_score_micro                                  [0.8880121396054628]
# f1_score_weighted                                   [0.8353395018439429]
# weighted_accuracy                                   [0.9843450583187134]
# precision_score_micro                               [0.8880121396054628]
# AUC_macro                                           [0.9010798429925516]
# average_precision_score_micro                       [0.9688318926888022]
# f1_score_micro                                      [0.8880121396054628]
# matthews_correlation                                               [0.0]
# balanced_accuracy                                                  [0.5]
# recall_score_macro                                                 [0.5]
# AUC_weighted                                        [0.9010798429925517]
# precision_score_weighted                             [0.788565560086672]
# AUC_micro                                           [0.9677841766045487]
# log_loss                                            [0.2741738187506259]
# average_precision_score_weighted                     [0.928476377825117]
# norm_macro_recall                                                  [0.0]
# average_precision_score_macro                       [0.7277523358032929]
# recall_score_weighted                               [0.8880121396054628]
# accuracy                                            [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
#
#                                  31a8f998-cd15-4050-9109-5ee3adf714c9_41  \
# precision_score_macro                               [0.7696003976510112]
# recall_score_micro                                  [0.9047040971168437]
# f1_score_weighted                                   [0.8964094947323111]
# weighted_accuracy                                   [0.9581616248183272]
# precision_score_micro                               [0.9047040971168437]
# AUC_macro                                           [0.9211813717590355]
# average_precision_score_micro                       [0.9740992367297003]
# f1_score_micro                                      [0.9047040971168437]
# matthews_correlation                               [0.45192337300620605]
# balanced_accuracy                                   [0.6893865298871718]
# recall_score_macro                                  [0.6893865298871718]
# AUC_weighted                                        [0.9211813717590356]
# precision_score_weighted                            [0.8931113592291784]
# AUC_micro                                           [0.9727568095311561]
# log_loss                                           [0.21120302950479872]
# average_precision_score_weighted                    [0.9386346959079018]
# norm_macro_recall                                   [0.3787730597743435]
# average_precision_score_macro                       [0.7615315653019931]
# recall_score_weighted                               [0.9047040971168437]
# accuracy                                            [0.9047040971168437]
# f1_score_macro                                      [0.7196653422552277]
#
#                                  31a8f998-cd15-4050-9109-5ee3adf714c9_2  \
# precision_score_macro                              [0.8193938012762079]
# recall_score_micro                                  [0.888619119878604]
# f1_score_weighted                                  [0.8373926979576183]
# weighted_accuracy                                  [0.9841359210553396]
# precision_score_micro                               [0.888619119878604]
# AUC_macro                                            [0.89226901325746]
# average_precision_score_micro                      [0.9658276892918809]
# f1_score_micro                                      [0.888619119878604]
# matthews_correlation                              [0.07053425306980969]
# balanced_accuracy                                  [0.5038941589005774]
# recall_score_macro                                 [0.5038941589005774]
# AUC_weighted                                         [0.89226901325746]
# precision_score_weighted                           [0.8732450758932834]
# AUC_micro                                          [0.9660359997328918]
# log_loss                                          [0.24875435227431936]
# average_precision_score_weighted                   [0.9284394539744922]
# norm_macro_recall                                [0.007788317801154854]
# average_precision_score_macro                      [0.7384291536138586]
# recall_score_weighted                               [0.888619119878604]
# accuracy                                            [0.888619119878604]
# f1_score_macro                                    [0.47852705178786353]
#
#                                  31a8f998-cd15-4050-9109-5ee3adf714c9_24  \
# precision_score_macro                               [0.7836182515310355]
# recall_score_micro                                  [0.9113808801213961]
# f1_score_weighted                                   [0.9075232070026762]
# weighted_accuracy                                   [0.9543911754422495]
# precision_score_micro                               [0.9113808801213961]
# AUC_macro                                           [0.9438841004951403]
# average_precision_score_micro                        [0.980258627086168]
# f1_score_micro                                      [0.9113808801213961]
# matthews_correlation                                [0.5197756567915791]
# balanced_accuracy                                   [0.7381429367950549]
# recall_score_macro                                  [0.7381429367950549]
# AUC_weighted                                        [0.9438841004951403]
# precision_score_weighted                            [0.9051091556982174]
# AUC_micro                                           [0.9792746171257781]
# log_loss                                            [0.1809974148381821]
# average_precision_score_weighted                    [0.9530284047649816]
# norm_macro_recall                                   [0.4762858735901099]
# average_precision_score_macro                       [0.8150378454592331]
# recall_score_weighted                               [0.9113808801213961]
# accuracy                                            [0.9113808801213961]
# f1_score_macro                                      [0.7580675984486392]
#
#                                  31a8f998-cd15-4050-9109-5ee3adf714c9_15  \
# precision_score_macro                               [0.4440060698027314]
# recall_score_micro                                  [0.8880121396054628]
# f1_score_weighted                                   [0.8353395018439429]
# weighted_accuracy                                   [0.9843450583187134]
# precision_score_micro                               [0.8880121396054628]
# AUC_macro                                           [0.8760454350954991]
# average_precision_score_micro                        [0.963558601900182]
# f1_score_micro                                      [0.8880121396054628]
# matthews_correlation                                               [0.0]
# balanced_accuracy                                                  [0.5]
# recall_score_macro                                                 [0.5]
# AUC_weighted                                        [0.8760454350954993]
# precision_score_weighted                             [0.788565560086672]
# AUC_micro                                           [0.9628050041332686]
# log_loss                                           [0.26377105528545525]
# average_precision_score_weighted                    [0.9217227970746547]
# norm_macro_recall                                                  [0.0]
# average_precision_score_macro                       [0.7117856444409363]
# recall_score_weighted                               [0.8880121396054628]
# accuracy                                            [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
#
#                                  31a8f998-cd15-4050-9109-5ee3adf714c9_17  \
# precision_score_macro                               [0.5998060344827586]
# recall_score_micro                                  [0.7138088012139605]
# f1_score_weighted                                   [0.7649138650968899]
# weighted_accuracy                                   [0.7109851790779496]
# precision_score_micro                               [0.7138088012139605]
# AUC_macro                                           [0.7987309367283693]
# average_precision_score_micro                        [0.781907087616291]
# f1_score_micro                                      [0.7138088012139605]
# matthews_correlation                                [0.2998300064555957]
# balanced_accuracy                                   [0.7251818570817288]
# recall_score_macro                                  [0.7251818570817288]
# AUC_weighted                                        [0.7987309367283693]
# precision_score_weighted                            [0.8761141620009418]
# AUC_micro                                           [0.8020298378238975]
# log_loss                                            [0.5831300527336283]
# average_precision_score_weighted                    [0.9015672455800903]
# norm_macro_recall                                  [0.45036371416345755]
# average_precision_score_macro                       [0.6947972845754087]
# recall_score_weighted                               [0.7138088012139605]
# accuracy                                            [0.7138088012139605]
# f1_score_macro                                      [0.5909116702251853]
#
#                                  31a8f998-cd15-4050-9109-5ee3adf714c9_12  \
# precision_score_macro                               [0.6037717935869662]
# recall_score_micro                                  [0.7226100151745068]
# f1_score_weighted                                   [0.7717117027712148]
# weighted_accuracy                                   [0.7204471743302232]
# precision_score_micro                               [0.7226100151745068]
# AUC_macro                                           [0.8512305338364389]
# average_precision_score_micro                       [0.8162721017145591]
# f1_score_micro                                      [0.7226100151745067]
# matthews_correlation                                [0.3098687021164699]
# balanced_accuracy                                   [0.7313215596270796]
# recall_score_macro                                  [0.7313215596270796]
# AUC_weighted                                         [0.851230533836439]
# precision_score_weighted                            [0.8777747986359666]
# AUC_micro                                           [0.8302814076600173]
# log_loss                                            [0.5953754862347297]
# average_precision_score_weighted                    [0.9188723813576428]
# norm_macro_recall                                  [0.46264311925415913]
# average_precision_score_macro                       [0.7148005670162034]
# recall_score_weighted                               [0.7226100151745068]
# accuracy                                            [0.7226100151745068]
# f1_score_macro                                      [0.5982959359414048]
#
#                                  31a8f998-cd15-4050-9109-5ee3adf714c9_36
# precision_score_macro                               [0.7821021110876873]
# recall_score_micro                                  [0.9104704097116844]
# f1_score_weighted                                   [0.9059729706274329]
# weighted_accuracy                                   [0.9551458631809997]
# precision_score_micro                               [0.9104704097116844]
# AUC_macro                                           [0.9432857828236518]
# average_precision_score_micro                       [0.9800443370180479]
# f1_score_micro                                      [0.9104704097116844]
# matthews_correlation                                [0.5100263931184434]
# balanced_accuracy                                   [0.7305255007437292]
# recall_score_macro                                  [0.7305255007437292]
# AUC_weighted                                        [0.9432857828236519]
# precision_score_weighted                            [0.9033572790158588]
# AUC_micro                                           [0.9790564173887414]
# log_loss                                           [0.18224569727817555]
# average_precision_score_weighted                    [0.9512084834534001]
# norm_macro_recall                                   [0.4610510014874585]
# average_precision_score_macro                        [0.807198286166676]
# recall_score_weighted                               [0.9104704097116844]
# accuracy                                            [0.9104704097116844]
# f1_score_macro                                      [0.7526402807816874]
#
# [21 rows x 49 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/31a8f998-cd15-4050-9109-5ee3adf714c9/model_data
# Downloaded azureml/31a8f998-cd15-4050-9109-5ee3adf714c9/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                                                                                 reg_lambda=1.3541666666666667,
#                                                                                                                                 scale_pos_weight=1,
#                                                                                                                                 seed=None,
#                                                                                                                                 silent=None,
#                                                                                                                                 subsample=0.6,
#                                                                                                                                 tree_method='auto',
#                                                                                                                                 verbose=-10,
#                                                                                                                                 verbosity=0))],
#                                                                                                       verbose=False))],
#                                                                                 flatten_transform=None,
#                                                                                 weights=[0.1111111111111111,
#                                                                                          0.3333333333333333,
#                                                                                          0.1111111111111111,
#                                                                                          0.1111111111111111,
#                                                                                          0.2222222222222222,
#                                                                                          0.1111111111111111]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#                   feature_sweeping_config=None, feature_sweeping_timeout=None,
#                   featurization_config=None, force_text_dnn=None,
#                   is_cross_validation=None, is_onnx_compatible=None, logger=None,
#                   observer=None, task=None, working_dir=None)),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(classification_labels=None,
#                                 estimators=[('44',
#                                              Pipeline(memory=None,
#                                                       steps=[('standardscalerwrapper',
#                                                               <azureml.automl.runtime.shared.model_wrappers.StandardScalerWrapper object at 0x7f15fe3fdc88>),
#                                                              ('xgboostclassifier',
#                                                               XGBoostClassifier(base_score=0.5,
#                                                                                 booster='gbtree',
#                                                                                 colsample_bylevel=1,
#                                                                                 colsample_bynode=1,
#                                                                                 colsample_bytree=1,
#                                                                                 e...
#                                                                                 objective='reg:logistic',
#                                                                                 random_state=0,
#                                                                                 reg_alpha=1.1458333333333335,
#                                                                                 reg_lambda=1.3541666666666667,
#                                                                                 scale_pos_weight=1,
#                                                                                 seed=None,
#                                                                                 silent=None,
#                                                                                 subsample=0.6,
#                                                                                 tree_method='auto',
#                                                                                 verbose=-10,
#                                                                                 verbosity=0))],
#                                                       verbose=False))],
#                                 flatten_transform=None,
#                                 weights=[0.1111111111111111, 0.3333333333333333,
#                                          0.1111111111111111, 0.1111111111111111,
#                                          0.2222222222222222, 0.1111111111111111]))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_ccb6e8ec_44a7_11eb_abae_000d3a5f94ecrow0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_ccb6e8ec_44a7_11eb_abae_000d3a5f94ecrow0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_ccb6e8ec_44a7_11eb_abae_000d3a5f94ecrow1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_ccb6e8ec_44a7_11eb_abae_000d3a5f94ecrow1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_ccb6e8ec_44a7_11eb_abae_000d3a5f94ec" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ccb6e8ec_44a7_11eb_abae_000d3a5f94eclevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ccb6e8ec_44a7_11eb_abae_000d3a5f94ecrow0_col0" class="data row0 col0" >28796</td>
#                         <td id="T_ccb6e8ec_44a7_11eb_abae_000d3a5f94ecrow0_col1" class="data row0 col1" >462</td>
#             </tr>
#             <tr>
#                         <th id="T_ccb6e8ec_44a7_11eb_abae_000d3a5f94eclevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ccb6e8ec_44a7_11eb_abae_000d3a5f94ecrow1_col0" class="data row1 col0" >1008</td>
#                         <td id="T_ccb6e8ec_44a7_11eb_abae_000d3a5f94ecrow1_col1" class="data row1 col1" >2684</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: 4ba91755-1e1f-403d-8970-e5bc4ea8c243,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/9b72f9e6-56c5-4c16-991b-19c652994860/resourceGroups/aml-quickstarts-131418/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-131418/PipelineRuns/PipelineSubmit/4ba91755-1e1f-403d-8970-e5bc4ea8c243)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  999ad985-47be-4c7c-8f7b-cbd02197c60d

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
