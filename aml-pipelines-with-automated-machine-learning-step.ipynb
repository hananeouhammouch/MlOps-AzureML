# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.19.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-131166
# aml-quickstarts-131166
# southcentralus
# 5a4ab2ba-6c51-4805-8155-58759ad589d8

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'auto-ml-exp'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: auto-ml-exp,
# Workspace: quick-starts-ws-131166)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "cpu-cluster"


# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS3_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=5)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes =2)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "Bank-marketing"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 15,
    "max_concurrent_iterations":4,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [f0e21576][55c705a5-ac6e-491f-bc96-98c8b14144ff], (This step will run and generate new outputs)
# Submitted PipelineRun b4dd46c4-8a07-4ef8-89ad-57b3884f5268
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/auto-ml-exp/runs/b4dd46c4-8a07-4ef8-89ad-57b3884f5268?wsid=/subscriptions/5a4ab2ba-6c51-4805-8155-58759ad589d8/resourcegroups/aml-quickstarts-131166/workspaces/quick-starts-ws-131166

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: b4dd46c4-8a07-4ef8-89ad-57b3884f5268
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/auto-ml-exp/runs/b4dd46c4-8a07-4ef8-89ad-57b3884f5268?wsid=/subscriptions/5a4ab2ba-6c51-4805-8155-58759ad589d8/resourcegroups/aml-quickstarts-131166/workspaces/quick-starts-ws-131166
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
# WARNING:azureml.pipeline.core.run:Expected a StepRun object but received <class 'azureml.core.run.Run'> instead.
# This usually indicates a package conflict with one of the dependencies of azureml-core or azureml-pipeline-core.
# Please check for package conflicts in your python environment
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'b4dd46c4-8a07-4ef8-89ad-57b3884f5268', 'status': 'Completed', 'startTimeUtc': '2020-12-20T22:30:08.774231Z', 'endTimeUtc': '2020-12-20T22:56:24.072794Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg131166.blob.core.windows.net/azureml/ExperimentRun/dcid.b4dd46c4-8a07-4ef8-89ad-57b3884f5268/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=wy8go1a7NGcdntOZc%2F2UJQWj%2F4%2BtwubGr0DIEnaHhWA%3D&st=2020-12-20T22%3A20%3A30Z&se=2020-12-21T06%3A30%3A30Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg131166.blob.core.windows.net/azureml/ExperimentRun/dcid.b4dd46c4-8a07-4ef8-89ad-57b3884f5268/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=z9LVyco32fpyhNFMsH5aP8O%2F16XcGAAGvOJLTDHuxRY%3D&st=2020-12-20T22%3A20%3A30Z&se=2020-12-21T06%3A30%3A30Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg131166.blob.core.windows.net/azureml/ExperimentRun/dcid.b4dd46c4-8a07-4ef8-89ad-57b3884f5268/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=2AXc0meRG7%2FTWY2hLITl5XEefBunaPXLuUA%2FtbLhql0%3D&st=2020-12-20T22%3A20%3A30Z&se=2020-12-21T06%3A30%3A30Z&sp=r'}}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/7a434dde-6ce5-4303-a806-089102ae1590/metrics_data
# Downloaded azureml/7a434dde-6ce5-4303-a806-089102ae1590/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  7a434dde-6ce5-4303-a806-089102ae1590_25  \
# log_loss                                            [0.3503628330075183]
# recall_score_micro                                  [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
# AUC_macro                                           [0.9049397329243286]
# AUC_micro                                            [0.968551882306617]
# weighted_accuracy                                   [0.9843450583187134]
# recall_score_weighted                               [0.8880121396054628]
# accuracy                                            [0.8880121396054628]
# precision_score_weighted                             [0.788565560086672]
# norm_macro_recall                                                  [0.0]
# f1_score_micro                                      [0.8880121396054628]
# f1_score_weighted                                   [0.8353395018439429]
# precision_score_macro                               [0.4440060698027314]
# average_precision_score_micro                       [0.9652988228270809]
# average_precision_score_macro                       [0.7620348053339692]
# balanced_accuracy                                                  [0.5]
# average_precision_score_weighted                    [0.9332950786486538]
# recall_score_macro                                                 [0.5]
# matthews_correlation                                               [0.0]
# AUC_weighted                                        [0.9049397329243288]
# precision_score_micro                               [0.8880121396054628]
#
#                                  7a434dde-6ce5-4303-a806-089102ae1590_17  \
# log_loss                                            [0.5809478270918035]
# recall_score_micro                                  [0.7511380880121397]
# f1_score_macro                                      [0.6146475848833574]
# AUC_macro                                           [0.7987318629167153]
# AUC_micro                                            [0.815321416318006]
# weighted_accuracy                                   [0.7570678104869174]
# recall_score_weighted                               [0.7511380880121397]
# accuracy                                            [0.7511380880121397]
# precision_score_weighted                            [0.8751513237697957]
# norm_macro_recall                                   [0.4545084070116163]
# f1_score_micro                                      [0.7511380880121397]
# f1_score_weighted                                   [0.7926211782032432]
# precision_score_macro                               [0.6091262869977095]
# average_precision_score_micro                       [0.7820394739960435]
# average_precision_score_macro                       [0.7005510212084534]
# balanced_accuracy                                   [0.7272542035058082]
# average_precision_score_weighted                    [0.9019944248497112]
# recall_score_macro                                  [0.7272542035058082]
# matthews_correlation                                [0.3149565521351204]
# AUC_weighted                                        [0.7987318629167152]
# precision_score_micro                               [0.7511380880121397]
#
#                                  7a434dde-6ce5-4303-a806-089102ae1590_38  \
# log_loss                                            [0.1915700092661147]
# recall_score_micro                                  [0.9101669195751139]
# f1_score_macro                                      [0.7628468108863069]
# AUC_macro                                           [0.9420872951039831]
# AUC_micro                                           [0.9784016339651056]
# weighted_accuracy                                   [0.9498116557405191]
# recall_score_weighted                               [0.9101669195751139]
# accuracy                                            [0.9101669195751139]
# precision_score_weighted                            [0.9061315228072785]
# norm_macro_recall                                   [0.5009697191982172]
# f1_score_micro                                      [0.9101669195751139]
# f1_score_weighted                                   [0.9078978381936921]
# precision_score_macro                               [0.7771501536153407]
# average_precision_score_micro                       [0.9794012816936545]
# average_precision_score_macro                       [0.8103909596928525]
# balanced_accuracy                                   [0.7504848595991086]
# average_precision_score_weighted                    [0.9517611885936117]
# recall_score_macro                                  [0.7504848595991086]
# matthews_correlation                                [0.5269607853197806]
# AUC_weighted                                        [0.9420872951039831]
# precision_score_micro                               [0.9101669195751139]
#
#                                  7a434dde-6ce5-4303-a806-089102ae1590_52  \
# log_loss                                           [0.22295893959650998]
# recall_score_micro                                  [0.8965098634294385]
# f1_score_macro                                      [0.5555450511050308]
# AUC_macro                                           [0.9479130198000545]
# AUC_micro                                           [0.9773240827943198]
# weighted_accuracy                                   [0.9837690397978212]
# recall_score_weighted                               [0.8965098634294385]
# accuracy                                            [0.8965098634294385]
# precision_score_weighted                            [0.8918088664806565]
# norm_macro_recall                                  [0.09009034041126474]
# f1_score_micro                                      [0.8965098634294385]
# f1_score_weighted                                   [0.8576403474021587]
# precision_score_macro                               [0.8735407066052228]
# average_precision_score_micro                       [0.9785038655391943]
# average_precision_score_macro                       [0.8242316101567981]
# balanced_accuracy                                   [0.5450451702056324]
# average_precision_score_weighted                    [0.9554938666271322]
# recall_score_macro                                  [0.5450451702056324]
# matthews_correlation                                [0.2594317228695398]
# AUC_weighted                                        [0.9479130198000544]
# precision_score_micro                               [0.8965098634294385]
#
#                                  7a434dde-6ce5-4303-a806-089102ae1590_53  \
# log_loss                                           [0.19800594050908027]
# recall_score_micro                                  [0.9153262518968134]
# f1_score_macro                                      [0.7660564011460705]
# AUC_macro                                           [0.9461791952164225]
# AUC_micro                                           [0.9801314816904262]
# weighted_accuracy                                   [0.9581765714066937]
# recall_score_weighted                               [0.9153262518968134]
# accuracy                                            [0.9153262518968134]
# precision_score_weighted                            [0.9087718110252617]
# norm_macro_recall                                  [0.48546532628689243]
# f1_score_micro                                      [0.9153262518968134]
# f1_score_weighted                                   [0.9110727417120467]
# precision_score_macro                               [0.7970404423015457]
# average_precision_score_micro                       [0.9810588554500831]
# average_precision_score_macro                       [0.8205463976764726]
# balanced_accuracy                                   [0.7427326631434462]
# average_precision_score_weighted                    [0.9544940162886787]
# recall_score_macro                                  [0.7427326631434462]
# matthews_correlation                                [0.5370341427550445]
# AUC_weighted                                        [0.9461791952164224]
# precision_score_micro                               [0.9153262518968134]
#
#                                  7a434dde-6ce5-4303-a806-089102ae1590_7  \
# log_loss                                          [0.28267721844904126]
# recall_score_micro                                 [0.8877086494688923]
# f1_score_macro                                    [0.47025723472668807]
# AUC_macro                                           [0.833101786246844]
# AUC_micro                                          [0.9542637140468959]
# weighted_accuracy                                  [0.9840086451067112]
# recall_score_weighted                              [0.8877086494688923]
# accuracy                                           [0.8877086494688923]
# precision_score_weighted                           [0.7885353698682389]
# norm_macro_recall                                                 [0.0]
# f1_score_micro                                     [0.8877086494688923]
# f1_score_weighted                                  [0.8351882663491892]
# precision_score_macro                             [0.44398907103825136]
# average_precision_score_micro                      [0.9534287152757326]
# average_precision_score_macro                      [0.7150840130067745]
# balanced_accuracy                                  [0.4998291182501709]
# average_precision_score_weighted                   [0.9150944457387886]
# recall_score_macro                                 [0.4998291182501709]
# matthews_correlation                            [-0.006187485935511464]
# AUC_weighted                                        [0.833101786246844]
# precision_score_micro                              [0.8877086494688923]
#
#                                  7a434dde-6ce5-4303-a806-089102ae1590_3  \
# log_loss                                           [0.5091720335341127]
# recall_score_micro                                 [0.8045523520485585]
# f1_score_macro                                      [0.674865286930258]
# AUC_macro                                          [0.8909153889898435]
# AUC_micro                                          [0.8714579730635232]
# weighted_accuracy                                  [0.8080448747171213]
# recall_score_weighted                              [0.8045523520485585]
# accuracy                                           [0.8045523520485585]
# precision_score_weighted                           [0.8953370626105539]
# norm_macro_recall                                  [0.5809701637686233]
# f1_score_micro                                     [0.8045523520485584]
# f1_score_weighted                                  [0.8342164765061802]
# precision_score_macro                              [0.6514961961115807]
# average_precision_score_micro                      [0.8568920963791702]
# average_precision_score_macro                      [0.7476906087222237]
# balanced_accuracy                                  [0.7904850818843117]
# average_precision_score_weighted                   [0.9319132428760144]
# recall_score_macro                                 [0.7904850818843117]
# matthews_correlation                              [0.41955874407588867]
# AUC_weighted                                       [0.8909153889898436]
# precision_score_micro                              [0.8045523520485585]
#
#                                  7a434dde-6ce5-4303-a806-089102ae1590_2  \
# log_loss                                          [0.24382252158050682]
# recall_score_micro                                 [0.8977238239757208]
# f1_score_macro                                     [0.5989383422984669]
# AUC_macro                                           [0.897796968400306]
# AUC_micro                                          [0.9674460545130918]
# weighted_accuracy                                  [0.9783529710425947]
# recall_score_weighted                              [0.8977238239757208]
# accuracy                                           [0.8977238239757208]
# precision_score_weighted                           [0.8796264889364951]
# norm_macro_recall                                 [0.14592745722399125]
# f1_score_micro                                     [0.8977238239757208]
# f1_score_weighted                                  [0.8675721245237616]
# precision_score_macro                              [0.7990082211746488]
# average_precision_score_micro                      [0.9665804568751262]
# average_precision_score_macro                      [0.7408175214964037]
# balanced_accuracy                                  [0.5729637286119956]
# average_precision_score_weighted                   [0.9290617641772427]
# recall_score_macro                                 [0.5729637286119956]
# matthews_correlation                              [0.29540991657385257]
# AUC_weighted                                        [0.897796968400306]
# precision_score_micro                              [0.8977238239757208]
#
#                                  7a434dde-6ce5-4303-a806-089102ae1590_11  \
# log_loss                                            [0.4677263349199561]
# recall_score_micro                                  [0.7344461305007587]
# f1_score_macro                                      [0.6365621759943527]
# AUC_macro                                           [0.9097614694533822]
# AUC_micro                                           [0.8507813144024261]
# weighted_accuracy                                   [0.7097542700390922]
# recall_score_weighted                               [0.7344461305007587]
# accuracy                                            [0.7344461305007587]
# precision_score_weighted                            [0.9147260842525299]
# norm_macro_recall                                   [0.6678012473904644]
# f1_score_micro                                      [0.7344461305007587]
# f1_score_weighted                                    [0.782930171124692]
# precision_score_macro                               [0.6426033913698388]
# average_precision_score_micro                        [0.866016508152903]
# average_precision_score_macro                       [0.7611414882412011]
# balanced_accuracy                                   [0.8339006236952322]
# average_precision_score_weighted                    [0.9370317813231861]
# recall_score_macro                                  [0.8339006236952322]
# matthews_correlation                                [0.4364188873980797]
# AUC_weighted                                        [0.9097614694533821]
# precision_score_micro                               [0.7344461305007587]
#
#                                  7a434dde-6ce5-4303-a806-089102ae1590_31  ...  \
# log_loss                                           [0.18012736943904312]  ...
# recall_score_micro                                  [0.9132018209408195]  ...
# f1_score_macro                                      [0.7642816263884915]  ...
# AUC_macro                                           [0.9442592067752529]  ...
# AUC_micro                                           [0.9795984627464707]  ...
# weighted_accuracy                                    [0.954939715235299]  ...
# recall_score_weighted                               [0.9132018209408195]  ...
# accuracy                                            [0.9132018209408195]  ...
# precision_score_weighted                            [0.9074329436294158]  ...
# norm_macro_recall                                  [0.49017777259112316]  ...
# f1_score_micro                                      [0.9132018209408195]  ...
# f1_score_weighted                                   [0.9096764096913943]  ...
# precision_score_macro                               [0.7884731106837775]  ...
# average_precision_score_micro                       [0.9805583578526404]  ...
# average_precision_score_macro                       [0.8198704441305439]  ...
# balanced_accuracy                                   [0.7450888862955616]  ...
# average_precision_score_weighted                    [0.9541411484948241]  ...
# recall_score_macro                                  [0.7450888862955616]  ...
# matthews_correlation                                [0.5317952742313653]  ...
# AUC_weighted                                         [0.944259206775253]  ...
# precision_score_micro                               [0.9132018209408195]  ...
#
#                                  7a434dde-6ce5-4303-a806-089102ae1590_32  \
# log_loss                                           [0.18438902755770786]
# recall_score_micro                                  [0.9119878603945372]
# f1_score_macro                                      [0.7597246696921418]
# AUC_macro                                           [0.9407813695361835]
# AUC_micro                                            [0.978414897266977]
# weighted_accuracy                                   [0.9547700139704612]
# recall_score_weighted                               [0.9119878603945372]
# accuracy                                            [0.9119878603945372]
# precision_score_weighted                            [0.9057755480984142]
# norm_macro_recall                                   [0.4793376641900391]
# f1_score_micro                                      [0.9119878603945372]
# f1_score_weighted                                   [0.9081566096944386]
# precision_score_macro                               [0.7854355288470023]
# average_precision_score_micro                       [0.9794493482917321]
# average_precision_score_macro                       [0.8071742282912644]
# balanced_accuracy                                   [0.7396688320950195]
# average_precision_score_weighted                    [0.9509461669750866]
# recall_score_macro                                  [0.7396688320950195]
# matthews_correlation                                 [0.523106107160623]
# AUC_weighted                                        [0.9407813695361834]
# precision_score_micro                               [0.9119878603945372]
#
#                                  7a434dde-6ce5-4303-a806-089102ae1590_21  \
# log_loss                                           [0.18420134724861562]
# recall_score_micro                                  [0.9125948406676783]
# f1_score_macro                                      [0.7638698118841445]
# AUC_macro                                           [0.9423114326837048]
# AUC_micro                                           [0.9790132195513965]
# weighted_accuracy                                   [0.9539729009155015]
# recall_score_weighted                               [0.9125948406676783]
# accuracy                                            [0.9125948406676783]
# precision_score_weighted                            [0.9071064203941039]
# norm_macro_recall                                  [0.49186250919241936]
# f1_score_micro                                      [0.9125948406676783]
# f1_score_weighted                                   [0.9092961593409308]
# precision_score_macro                               [0.7861246045360897]
# average_precision_score_micro                       [0.9800058297942514]
# average_precision_score_macro                       [0.8130064306176901]
# balanced_accuracy                                   [0.7459312545962097]
# average_precision_score_weighted                    [0.9524012051949555]
# recall_score_macro                                  [0.7459312545962097]
# matthews_correlation                                 [0.530535514228425]
# AUC_weighted                                        [0.9423114326837048]
# precision_score_micro                               [0.9125948406676783]
#
#                                  7a434dde-6ce5-4303-a806-089102ae1590_30  \
# log_loss                                            [0.1858855432333583]
# recall_score_micro                                  [0.9092564491654022]
# f1_score_macro                                      [0.7519405667519964]
# AUC_macro                                           [0.9400441236128014]
# AUC_micro                                           [0.9782191714581113]
# weighted_accuracy                                   [0.9532122345414047]
# recall_score_weighted                               [0.9092564491654022]
# accuracy                                            [0.9092564491654022]
# precision_score_weighted                            [0.9026893654928896]
# norm_macro_recall                                   [0.4644204746900509]
# f1_score_micro                                       [0.909256449165402]
# f1_score_weighted                                   [0.9052396183263401]
# precision_score_macro                               [0.7773756867569583]
# average_precision_score_micro                       [0.9792529378468265]
# average_precision_score_macro                       [0.8043768280782629]
# balanced_accuracy                                   [0.7322102373450254]
# average_precision_score_weighted                    [0.9502272244802092]
# recall_score_macro                                  [0.7322102373450254]
# matthews_correlation                                [0.5075804332539731]
# AUC_weighted                                        [0.9400441236128014]
# precision_score_micro                               [0.9092564491654022]
#
#                                  7a434dde-6ce5-4303-a806-089102ae1590_44  \
# log_loss                                           [0.17788346285786574]
# recall_score_micro                                  [0.9159332321699545]
# f1_score_macro                                      [0.7749361894045931]
# AUC_macro                                           [0.9463227544100459]
# AUC_micro                                           [0.9799944275710886]
# weighted_accuracy                                   [0.9550275551853912]
# recall_score_weighted                               [0.9159332321699545]
# accuracy                                            [0.9159332321699545]
# precision_score_weighted                            [0.9112858568424094]
# norm_macro_recall                                   [0.5169362800941748]
# f1_score_micro                                      [0.9159332321699545]
# f1_score_weighted                                   [0.9131760047232391]
# precision_score_macro                               [0.7947825361313043]
# average_precision_score_micro                       [0.9809272175719745]
# average_precision_score_macro                       [0.8186176268448488]
# balanced_accuracy                                   [0.7584681400470874]
# average_precision_score_weighted                    [0.9540769305581739]
# recall_score_macro                                  [0.7584681400470874]
# matthews_correlation                                [0.5520575833451492]
# AUC_weighted                                         [0.946322754410046]
# precision_score_micro                               [0.9159332321699545]
#
#                                  7a434dde-6ce5-4303-a806-089102ae1590_47  \
# log_loss                                           [0.17910532907211624]
# recall_score_micro                                  [0.9110773899848255]
# f1_score_macro                                      [0.7607040409906504]
# AUC_macro                                           [0.9441971521560739]
# AUC_micro                                           [0.9792899988716983]
# weighted_accuracy                                    [0.952584822751283]
# recall_score_weighted                               [0.9110773899848255]
# accuracy                                            [0.9110773899848255]
# precision_score_weighted                            [0.9057257611710879]
# norm_macro_recall                                  [0.48778542809351544]
# f1_score_micro                                      [0.9110773899848255]
# f1_score_weighted                                   [0.9079110292671074]
# precision_score_macro                               [0.7813247168372088]
# average_precision_score_micro                       [0.9802828970248698]
# average_precision_score_macro                       [0.8125309596055054]
# balanced_accuracy                                   [0.7438927140467577]
# average_precision_score_weighted                    [0.9525150204219331]
# recall_score_macro                                  [0.7438927140467577]
# matthews_correlation                                [0.5238818520157478]
# AUC_weighted                                        [0.9441971521560738]
# precision_score_micro                               [0.9110773899848255]
#
#                                  7a434dde-6ce5-4303-a806-089102ae1590_50  \
# log_loss                                            [0.2102222983549571]
# recall_score_micro                                  [0.9119878603945372]
# f1_score_macro                                       [0.762847036773042]
# AUC_macro                                           [0.9400506069312231]
# AUC_micro                                           [0.9785210036819478]
# weighted_accuracy                                    [0.953300074491497]
# recall_score_weighted                               [0.9119878603945372]
# accuracy                                            [0.9119878603945372]
# precision_score_weighted                            [0.9066209162193739]
# norm_macro_recall                                  [0.49117898219310296]
# f1_score_micro                                      [0.9119878603945372]
# f1_score_weighted                                   [0.9087915779135559]
# precision_score_macro                               [0.7840916639346194]
# average_precision_score_micro                       [0.9795125449248038]
# average_precision_score_macro                       [0.8098370387850273]
# balanced_accuracy                                   [0.7455894910965515]
# average_precision_score_weighted                    [0.9514155002291758]
# recall_score_macro                                  [0.7455894910965515]
# matthews_correlation                                [0.5282799529434207]
# AUC_weighted                                         [0.940050606931223]
# precision_score_micro                               [0.9119878603945372]
#
#                                  7a434dde-6ce5-4303-a806-089102ae1590_9  \
# log_loss                                           [0.5605095314253244]
# recall_score_micro                                 [0.7229135053110773]
# f1_score_macro                                      [0.598145450071726]
# AUC_macro                                          [0.8247387685770228]
# AUC_micro                                          [0.8224824940533895]
# weighted_accuracy                                  [0.7210775754380184]
# recall_score_weighted                              [0.7229135053110773]
# accuracy                                           [0.7229135053110773]
# precision_score_weighted                           [0.8773987222654231]
# norm_macro_recall                                  [0.4606166191532046]
# f1_score_micro                                     [0.7229135053110773]
# f1_score_weighted                                  [0.7719101108816505]
# precision_score_macro                              [0.6034606503151719]
# average_precision_score_micro                      [0.7911664704100223]
# average_precision_score_macro                      [0.7079891219338545]
# balanced_accuracy                                  [0.7303083095766023]
# average_precision_score_weighted                   [0.9109227054110847]
# recall_score_macro                                 [0.7303083095766023]
# matthews_correlation                               [0.3087254280540118]
# AUC_weighted                                       [0.8247387685770227]
# precision_score_micro                              [0.7229135053110773]
#
#                                  7a434dde-6ce5-4303-a806-089102ae1590_14  \
# log_loss                                           [0.26114456542110615]
# recall_score_micro                                  [0.8943854324734446]
# f1_score_macro                                      [0.5515365697980026]
# AUC_macro                                           [0.8879261161032663]
# AUC_micro                                           [0.9653740320207423]
# weighted_accuracy                                   [0.9817081352095977]
# recall_score_weighted                               [0.8943854324734446]
# accuracy                                            [0.8943854324734446]
# precision_score_weighted                            [0.8783297770514765]
# norm_macro_recall                                   [0.0853297323130442]
# f1_score_micro                                      [0.8943854324734446]
# f1_score_weighted                                   [0.8558283233075843]
# precision_score_macro                                [0.814974358974359]
# average_precision_score_micro                       [0.9662776437853848]
# average_precision_score_macro                       [0.7330509157071284]
# balanced_accuracy                                   [0.5426648661565221]
# average_precision_score_weighted                    [0.9277762843997557]
# recall_score_macro                                  [0.5426648661565221]
# matthews_correlation                               [0.23184769887473441]
# AUC_weighted                                        [0.8879261161032665]
# precision_score_micro                               [0.8943854324734446]
#
#                                  7a434dde-6ce5-4303-a806-089102ae1590_33  \
# log_loss                                            [0.1780776949679011]
# recall_score_micro                                    [0.91350531107739]
# f1_score_macro                                      [0.7660249518570629]
# AUC_macro                                           [0.9454956682171061]
# AUC_micro                                           [0.9798544260513353]
# weighted_accuracy                                   [0.9546881526557157]
# recall_score_weighted                                 [0.91350531107739]
# accuracy                                              [0.91350531107739]
# precision_score_weighted                            [0.9080100799328442]
# norm_macro_recall                                  [0.49525606329200667]
# f1_score_micro                                        [0.91350531107739]
# f1_score_weighted                                   [0.9101791103151579]
# precision_score_macro                               [0.7889312152158643]
# average_precision_score_micro                       [0.9808030510504245]
# average_precision_score_macro                       [0.8183292144360064]
# balanced_accuracy                                   [0.7476280316460033]
# average_precision_score_weighted                    [0.9539319641567288]
# recall_score_macro                                  [0.7476280316460033]
# matthews_correlation                                [0.5349671694786223]
# AUC_weighted                                        [0.9454956682171062]
# precision_score_micro                                 [0.91350531107739]
#
#                                  7a434dde-6ce5-4303-a806-089102ae1590_48
# log_loss                                            [0.4012580312902106]
# recall_score_micro                                  [0.8446130500758725]
# f1_score_macro                                      [0.7321648567981203]
# AUC_macro                                           [0.9243192978751388]
# AUC_micro                                             [0.91167617280056]
# weighted_accuracy                                   [0.8409858907655032]
# recall_score_weighted                               [0.8446130500758725]
# accuracy                                            [0.8446130500758725]
# precision_score_weighted                            [0.9179245887020234]
# norm_macro_recall                                   [0.7184452261474084]
# f1_score_micro                                      [0.8446130500758725]
# f1_score_weighted                                   [0.8668393440164867]
# precision_score_macro                               [0.6958184225088152]
# average_precision_score_micro                       [0.8847888105365734]
# average_precision_score_macro                       [0.7558166048426511]
# balanced_accuracy                                   [0.8592226130737042]
# average_precision_score_weighted                    [0.9367337606046351]
# recall_score_macro                                  [0.8592226130737042]
# matthews_correlation                                [0.5304428543079349]
# AUC_weighted                                        [0.9243192978751389]
# precision_score_micro                               [0.8446130500758725]
#
# [21 rows x 53 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/7a434dde-6ce5-4303-a806-089102ae1590/model_data
# Downloaded azureml/7a434dde-6ce5-4303-a806-089102ae1590/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                                                                                  silent=True,
#                                                                                                                                  subsample=0.14894736842105263,
#                                                                                                                                  subsample_for_bin=200000,
#                                                                                                                                  subsample_freq=0,
#                                                                                                                                  verbose=-10))],
#                                                                                                       verbose=False))],
#                                                                                 flatten_transform=None,
#                                                                                 weights=[0.07142857142857142,
#                                                                                          0.07142857142857142,
#                                                                                          0.21428571428571427,
#                                                                                          0.07142857142857142,
#                                                                                          0.07142857142857142,
#                                                                                          0.42857142857142855,
#                                                                                          0.07142857142857142]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#                   feature_sweeping_config=None, feature_sweeping_timeout=None,
#                   featurization_config=None, force_text_dnn=None,
#                   is_cross_validation=None, is_onnx_compatible=None, logger=None,
#                   observer=None, task=None, working_dir=None)),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(classification_labels=None,
#                                 estimators=[('44',
#                                              Pipeline(memory=None,
#                                                       steps=[('standardscalerwrapper',
#                                                               <azureml.automl.runtime.shared.model_wrappers.StandardScalerWrapper object at 0x7fe22ccf2908>),
#                                                              ('xgboostclassifier',
#                                                               XGBoostClassifier(base_score=0.5,
#                                                                                 booster='gbtree',
#                                                                                 colsample_bylevel=1,
#                                                                                 colsample_bynode=1,
#                                                                                 colsample_bytree=1,
#                                                                                 e...
#                                                                                  random_state=None,
#                                                                                  reg_alpha=0.21052631578947367,
#                                                                                  reg_lambda=0.894736842105263,
#                                                                                  silent=True,
#                                                                                  subsample=0.14894736842105263,
#                                                                                  subsample_for_bin=200000,
#                                                                                  subsample_freq=0,
#                                                                                  verbose=-10))],
#                                                       verbose=False))],
#                                 flatten_transform=None,
#                                 weights=[0.07142857142857142, 0.07142857142857142,
#                                          0.21428571428571427, 0.07142857142857142,
#                                          0.07142857142857142, 0.42857142857142855,
#                                          0.07142857142857142]))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_a16a4356_4316_11eb_94e7_000d3aeaf7derow0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_a16a4356_4316_11eb_94e7_000d3aeaf7derow0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_a16a4356_4316_11eb_94e7_000d3aeaf7derow1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_a16a4356_4316_11eb_94e7_000d3aeaf7derow1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_a16a4356_4316_11eb_94e7_000d3aeaf7de" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a16a4356_4316_11eb_94e7_000d3aeaf7delevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a16a4356_4316_11eb_94e7_000d3aeaf7derow0_col0" class="data row0 col0" >29252</td>
#                         <td id="T_a16a4356_4316_11eb_94e7_000d3aeaf7derow0_col1" class="data row0 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_a16a4356_4316_11eb_94e7_000d3aeaf7delevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_a16a4356_4316_11eb_94e7_000d3aeaf7derow1_col0" class="data row1 col0" >3210</td>
#                         <td id="T_a16a4356_4316_11eb_94e7_000d3aeaf7derow1_col1" class="data row1 col1" >482</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: 33c5ec36-6351-457d-bf04-63e464870992,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/5a4ab2ba-6c51-4805-8155-58759ad589d8/resourceGroups/aml-quickstarts-131166/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-131166/PipelineRuns/PipelineSubmit/33c5ec36-6351-457d-bf04-63e464870992)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  44229fb8-eb77-4a26-8b40-0138a43ebe5a

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
